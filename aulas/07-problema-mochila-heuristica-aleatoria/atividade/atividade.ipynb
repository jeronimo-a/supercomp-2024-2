# %% [markdown]
# ### Atividade 07, Supercomputação 2024-2
#
# #### Heurítica aletória
#
# Jerônimo de Abreu Afrange

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# #### Comparação dos tempos de execução

# %%
entradas = list(range(30))
resultados_exaustiva    = [1.117e-5, 1.3928e-5, 1.4859e-5, 4.2467e-5, 6.0587e-5, 8.3997e-5, 1.33645e-4, 3.70953e-4, 2.13133e-3, 1.74151e-3, 5.1323e-3, 7.13044e-3, 2.00255e-2, 4.95194e-2, 9.79794e-2, 1.88654e-1, 3.264756e-1, 6.88967e-1, 1.45473, 3.1624, 6.98119, 13.2651, 27.2072, 55.5235, 113.509, 232.441, 479.409, 976.278, 1274.63]
resultados_shuffle      = [1.128e-06, 1.31e-06, 1.789e-06, 1.852e-06, 2.208e-06, 2.127e-06, 2.346e-06, 2.41e-06, 2.877e-06, 2.948e-06, 3.055e-06, 3.344e-06, 3.408e-06, 2.763e-06, 3.324e-06, 3.482e-06, 3.631e-06, 3.41e-06, 3.667e-06, 3.921e-06, 3.697e-06, 4.024e-06, 3.839e-06, 3.201e-06, 3.91e-06, 3.102e-06, 9.75e-06, 4.079e-06, 4.018e-06, 3.765e-06]
resultados_chance       = [4.45e-07, 7.32e-07, 5.78e-07, 6.6e-07, 7.23e-07, 8.22e-07, 8.33e-07, 1.27e-06, 8.42e-07, 9.22e-07, 1.063e-06, 1.059e-06, 1.618e-06, 1.592e-06, 1.122e-06, 1.94e-06, 1.722e-06, 2.067e-06, 1.181e-06, 1.243e-06, 1.292e-06, 1.41e-06, 1.405e-06, 1.37e-06, 2.554e-06, 1.572e-06, 2.614e-06, 2.57e-06, 2.61e-06]

plt.plot(entradas[:-1], resultados_exaustiva)
plt.plot(entradas, resultados_shuffle)
plt.plot(entradas, resultados_chance)
plt.legend(["Exaustiva", "Aleatória Shuffle", "Aleatória Chance"])
plt.title("Tempo de execução vs quantidade de itens")
plt.xlabel("Quantidade de itens")
plt.ylabel("Tempo de execução (s)")
plt.yscale("log")
plt.show()
